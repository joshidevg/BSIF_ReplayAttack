# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import csv
import cv2
import time
import pickle

# %%
from testing import plot_and_print
from training import train_model

# %%
train_model('small_training.csv', 'small_Webcam_Attack_Model.pkl')
# Out:
# Training time:  12.222729206085205  seconds for  small_training.csv  file.

# %%
train_model('small_bsif_13_training.csv', 'small_BSIF_13_Webcam_Attack_Model.pkl')
# Out:
# Training time:  12.240440607070923  seconds for  small_bsif_13_training.csv  file.

# %%
train_model('small_bsif_17_training.csv', 'small_BSIF_17_Webcam_Attack_Model.pkl')
# Out:
# Training time:  12.1051504611969  seconds for  small_bsif_17_training.csv  file.

# %%
train_model('small_bsif_21_training.csv', 'small_BSIF_21_Webcam_Attack_Model.pkl')
# Out:
# Training time:  11.514878511428833  seconds for  small_bsif_21_training.csv  file.

# %%
train_model('big_training.csv', 'big_Webcam_Attack_Model.pkl')
# Out:
# Training time:  28.052032709121704  seconds for  big_training.csv  file.

# %%
train_model('big_bsif_13_training.csv', 'big_BSIF_13_Webcam_Attack_Model.pkl')
# Out:
# Training time:  27.513036727905273  seconds for  big_bsif_13_training.csv  file.

# %%
train_model('big_bsif_17_training.csv', 'big_BSIF_17_Webcam_Attack_Model.pkl')
# Out:
# Training time:  26.5385103225708  seconds for  big_bsif_17_training.csv  file.

# %%
train_model('big_bsif_21_training.csv', 'big_BSIF_21_Webcam_Attack_Model.pkl')
# Out:
# Training time:  26.836898803710938  seconds for  big_bsif_21_training.csv  file.

# %%
plot_and_print('small_Webcam_Attack_Model.pkl', 'small_testing.csv', 'a portion of the testing data')
# Out:
# The scores for a portion of the testing data are:
# EER:  0.004020100502512563
# HTER:  0.0214199759326113
# FAR:  0.0
# FRR:  0.0428399518652226

# %%
plot_and_print('small_Webcam_Attack_Model.pkl', 'small_training.csv', 'a portion of the testing data')
# Out:
# The scores for a portion of the testing data are:
# EER:  0.0
# HTER:  0.0
# FAR:  0.0
# FRR:  0.0

# %%
plot_and_print('small_BSIF_13_Webcam_Attack_Model.pkl', 'small_BSIF_13_testing.csv', 'a portion of the testing data with 13x13 patch')
# Out:
# The scores for a portion of the testing data with 13x13 patch are:
# EER:  0.004628099173553719
# HTER:  0.015917375455650085
# FAR:  0.0
# FRR:  0.03183475091130017

# %%
plot_and_print('small_BSIF_13_Webcam_Attack_Model.pkl', 'small_BSIF_13_training.csv', 'a portion of the testing data with 13x13 patch')
# Out:
# The scores for a portion of the testing data with 13x13 patch are:
# EER:  0.0
# HTER:  0.0
# FAR:  0.0
# FRR:  0.0

# %%
plot_and_print('small_BSIF_17_Webcam_Attack_Model.pkl', 'small_BSIF_17_testing.csv', 'a portion of the testing data with 17x17 patch')
# Out:
# The scores for a portion of the testing data with 17x17 patch are:
# EER:  0.004680708793045804
# HTER:  0.04121475054229934
# FAR:  0.0
# FRR:  0.08242950108459868

# %%
plot_and_print('small_BSIF_17_Webcam_Attack_Model.pkl', 'small_BSIF_17_training.csv', 'a portion of the testing data with 17x17 patch')
# Out:
# The scores for a portion of the testing data with 17x17 patch are:
# EER:  0.0
# HTER:  0.0
# FAR:  0.0
# FRR:  0.0

# %%
plot_and_print('small_BSIF_21_Webcam_Attack_Model.pkl', 'small_BSIF_21_testing.csv', 'a portion of the testing data with 21x21 patch')
# Out:
# The scores for a portion of the testing data with 21x21 patch are:
# EER:  0.005394470667565745
# HTER:  0.008864398658361305
# FAR:  0.0
# FRR:  0.01772879731672261

# %%
plot_and_print('small_BSIF_21_Webcam_Attack_Model.pkl', 'small_BSIF_21_training.csv', 'a portion of the testing data with 21x21 patch')
# Out:
# The scores for a portion of the testing data with 21x21 patch are:
# EER:  0.0
# HTER:  0.0
# FAR:  0.0
# FRR:  0.0

# %%
plot_and_print('big_Webcam_Attack_Model.pkl', 'big_testing.csv', 'the entire testing data')
# Out:
# The scores for the entire testing data are:
# EER:  0.003997867803837953
# HTER:  0.026459008800370554
# FAR:  0.0
# FRR:  0.05291801760074111

# %%
plot_and_print('big_Webcam_Attack_Model.pkl', 'big_training.csv', 'the entire testing data')
# Out:
# The scores for the entire testing data are:
# EER:  0.0
# HTER:  0.0
# FAR:  0.0
# FRR:  0.0

# %%
plot_and_print('big_BSIF_13_Webcam_Attack_Model.pkl', 'big_BSIF_13_testing.csv', 'full testing data with 13x13 patch')
# Out:
# The scores for full testing data with 13x13 patch are:
# EER:  0.003975089439512389
# HTER:  0.010189488737933516
# FAR:  0.0
# FRR:  0.020378977475867033

# %%
plot_and_print('big_BSIF_13_Webcam_Attack_Model.pkl', 'big_BSIF_13_training.csv', 'full testing data with 13x13 patch')
# Out:
# The scores for full testing data with 13x13 patch are:
# EER:  0.0
# HTER:  0.0
# FAR:  0.0
# FRR:  0.0

# %%
plot_and_print('big_BSIF_17_Webcam_Attack_Model.pkl', 'big_BSIF_17_testing.csv', 'full testing data with 17x17 patch')
# Out:
# The scores for full testing data with 17x17 patch are:
# EER:  0.0034787262510034785
# HTER:  0.03732133403917415
# FAR:  0.0
# FRR:  0.0746426680783483

# %%
plot_and_print('big_BSIF_17_Webcam_Attack_Model.pkl', 'big_BSIF_17_training.csv', 'full testing data with 17x17 patch')
# Out:
# The scores for full testing data with 17x17 patch are:
# EER:  0.0
# HTER:  0.0
# FAR:  0.0
# FRR:  0.0

# %%
plot_and_print('big_BSIF_21_Webcam_Attack_Model.pkl', 'big_BSIF_21_testing.csv', 'full testing data with 21x21 patch')
# Out:
# The scores for full testing data with 21x21 patch are:
# EER:  0.0042570174271650925
# HTER:  0.09210526315789475
# FAR:  0.0
# FRR:  0.1842105263157895

# %%
plot_and_print('big_BSIF_21_Webcam_Attack_Model.pkl', 'big_BSIF_21_training.csv', 'full testing data with 21x21 patch')
# Out:
# The scores for full testing data with 21x21 patch are:
# EER:  0.0
# HTER:  0.0
# FAR:  0.0
# FRR:  0.0
